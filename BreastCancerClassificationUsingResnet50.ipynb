# %% [markdown]
# # **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Loading & Preprocessing

# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from keras.applications.resnet import ResNet50
from tensorflow.keras.optimizers import Adam
from keras.applications.densenet import DenseNet201
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools


# %matplotlib inline

# %%
#Transfer 'jpg' images to an array IMG
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".png":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

benign_train = np.array(Dataset_loader('/content/drive/MyDrive/BreastCancerProject/DataSet/CBISDatasetforBenignandMalignent/train/Benign',224))
malign_train = np.array(Dataset_loader('/content/drive/MyDrive/BreastCancerProject/DataSet/CBISDatasetforBenignandMalignent/train/Malignant',224))
benign_test = np.array(Dataset_loader('/content/drive/MyDrive/BreastCancerProject/DataSet/CBISDatasetforBenignandMalignent/test/Benign',224))
malign_test = np.array(Dataset_loader('/content/drive/MyDrive/BreastCancerProject/DataSet/CBISDatasetforBenignandMalignent/test/Malignant',224))
# Out:
# 100%|██████████| 1616/1616 [00:21<00:00, 74.61it/s]
# 100%|██████████| 1317/1317 [00:21<00:00, 60.70it/s]
# 100%|██████████| 178/178 [00:03<00:00, 52.45it/s]
# 100%|██████████| 116/116 [00:03<00:00, 37.89it/s]

# %% [markdown]
# # Create Label

# %%
# Create labels
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))

# Merge data 
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)

# Shuffle train data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# Shuffle test data
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# To categorical
Y_train = to_categorical(Y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)

# %% [markdown]
# # Train and Evalutation split

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X_train, Y_train, 
    test_size=0.2, 
    random_state=11
)

# %% [markdown]
# # Display Some Images

# %%
# # Display first 15 images of moles, and how they are classified
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(Y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(x_train[i], interpolation='nearest')
plt.show()

# %% [markdown]
# # Data Generator

# %%
BATCH_SIZE = 32

# Using original generator
train_generator = ImageDataGenerator(
        zoom_range=2,  # set range for random zoom
        rotation_range = 90,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
    )

# %% [markdown]
# # Model: ResNet50

# %%
def build_model(backbone, lr=1e-4):
    model = Sequential()
    model.add(backbone)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.3))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(2, activation='softmax'))
    
    
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(lr=lr),
        metrics=['accuracy']
    )
    
    return model

# %%
K.clear_session()
gc.collect()

resnet = DenseNet201(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)


model = build_model(resnet ,lr = 1e-4)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 1s 0us/step
# 74850304/74836368 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 7, 7, 1920)        18321984
#
#  global_average_pooling2d (G  (None, 1920)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1920)              0
#
#  batch_normalization (BatchN  (None, 1920)             7680
#  ormalization)
#
#  dense (Dense)               (None, 2)                 3842
#
# =================================================================
# Total params: 18,333,506
# Trainable params: 18,100,610
# Non-trainable params: 232,896
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# Learning Rate Reducer
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=5,verbose=1,factor=0.2, min_lr=1e-4)

# Checkpoint
filepath="/content/drive/MyDrive/BreastCancerProject/Models/weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# %% [markdown]
# # Training & Evaluation

# %%
history = model.fit_generator(
    train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
    epochs=50,
    validation_data=(x_val, y_val),
    callbacks=[learn_control, checkpoint]
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/50
# 74/73 [==============================] - ETA: 0s - loss: 0.7356 - accuracy: 0.5780
# Epoch 1: val_accuracy improved from -inf to 0.56899, saving model to /content/drive/MyDrive/BreastCancerProject/Models/weights.best.hdf5
# 73/73 [==============================] - 101s 829ms/step - loss: 0.7356 - accuracy: 0.5780 - val_loss: 0.6701 - val_accuracy: 0.5690 - lr: 1.0000e-04
# Epoch 2/50
# 74/73 [==============================] - ETA: 0s - loss: 0.7101 - accuracy: 0.6014
# Epoch 2: val_accuracy improved from 0.56899 to 0.57240, saving model to /content/drive/MyDrive/BreastCancerProject/Models/weights.best.hdf5
# 73/73 [==============================] - 50s 673ms/step - loss: 0.7101 - accuracy: 0.6014 - val_loss: 0.6459 - val_accuracy: 0.5724 - lr: 1.0000e-04
# Epoch 3/50
# 74/73 [==============================] - ETA: 0s - loss: 0.6801 - accuracy: 0.6189
# Epoch 3: val_accuracy improved from 0.57240 to 0.60988, saving model to /content/drive/MyDrive/BreastCancerProject/Models/weights.best.hdf5
# 73/73 [==============================] - 50s 672ms/step - loss: 0.6801 - accuracy: 0.6189 - val_loss: 0.6733 - val_accuracy: 0.6099 - lr: 1.0000e-04
# Epoch 4/50
# 74/73 [==============================] - ETA: 0s - loss: 0.6601 - accuracy: 0.6262
# Epoch 4: val_accuracy improved from 0.60988 to 0.66951, saving model to /content/drive/MyDrive/BreastCancerProject/Models/weights.best.hdf5
# 73/73 [==============================] - 49s 670ms/step - loss: 0.6601 - accuracy: 0.6262 - val_loss: 0.6117 - val_accuracy: 0.6695 - lr: 1.0000e-04
# Epoch 5/50
# 74/73 [==============================] - ETA: 0s - loss: 0.6413 - accuracy: 0.6398
# Epoch 5: val_accuracy improved from 0.66951 to 0.67802, saving model to /content/drive/MyDrive/BreastCancerProject/Models/weights.best.hdf5
# 73/73 [==============================] - 50s 684ms/step - loss: 0.6413 - accuracy: 0.6398 - val_loss: 0.5969 - val_accuracy: 0.6780 - lr: 1.0000e-04
# Epoch 6/50
# 74/73 [==============================] - ETA: 0s - loss: 0.6411 - accuracy: 0.6428
# Epoch 6: val_accuracy did not improve from 0.67802
# 73/73 [==============================] - 44s 599ms/step - loss: 0.6411 - accuracy: 0.6428 - val_loss: 0.6985 - val_accuracy: 0.5894 - lr: 1.0000e-04
# Epoch 7/50
# 74/73 [==============================] - ETA: 0s - loss: 0.6260 - accuracy: 0.6415
# Epoch 7: val_accuracy did not improve from 0.67802
# 73/73 [==============================] - 44s 595ms/step - loss: 0.6260 - accuracy: 0.6415 - val_loss: 0.5718 - val_accuracy: 0.6712 - lr: 1.0000e-04
# Epoch 8/50
# 74/73 [==============================] - ETA: 0s - loss: 0.6063 - accuracy: 0.6697
# Epoch 8: val_accuracy did not improve from 0.67802
# 73/73 [==============================] - 44s 596ms/step - loss: 0.6063 - accuracy: 0.6697 - val_loss: 0.6563 - val_accuracy: 0.6337 - lr: 1.0000e-04
# Epoch 9/50
# 74/73 [==============================] - ETA: 0s - loss: 0.6106 - accuracy: 0.6513
# Epoch 9: val_accuracy improved from 0.67802 to 0.68484, saving model to /content/drive/MyDrive/BreastCancerProject/Models/weights.best.hdf5
# 73/73 [==============================] - 49s 668ms/step - loss: 0.6106 - accuracy: 0.6513 - val_loss: 0.5689 - val_accuracy: 0.6848 - lr: 1.0000e-04
# Epoch 10/50
# 74/73 [==============================] - ETA: 0s - loss: 0.6090 - accuracy: 0.6586
# Epoch 10: val_accuracy improved from 0.68484 to 0.70358, saving model to /content/drive/MyDrive/BreastCancerProject/Models/weights.best.hdf5
# 73/73 [==============================] - 50s 683ms/step - loss: 0.6090 - accuracy: 0.6586 - val_loss: 0.5356 - val_accuracy: 0.7036 - lr: 1.0000e-04
# Epoch 11/50
# 74/73 [==============================] - ETA: 0s - loss: 0.6042 - accuracy: 0.6645
# Epoch 11: val_accuracy did not improve from 0.70358
# 73/73 [==============================] - 44s 600ms/step - loss: 0.6042 - accuracy: 0.6645 - val_loss: 0.5797 - val_accuracy: 0.6780 - lr: 1.0000e-04
# Epoch 12/50
# 74/73 [==============================] - ETA: 0s - loss: 0.5864 - accuracy: 0.6803
# Epoch 12: val_accuracy did not improve from 0.70358
# 73/73 [==============================] - 47s 633ms/step - loss: 0.5864 - accuracy: 0.6803 - val_loss: 0.6357 - val_accuracy: 0.5877 - lr: 1.0000e-04
# Epoch 13/50
# 74/73 [==============================] - ETA: 0s - loss: 0.5999 - accuracy: 0.6714
# Epoch 13: val_accuracy did not improve from 0.70358
# 73/73 [==============================] - 44s 599ms/step - loss: 0.5999 - accuracy: 0.6714 - val_loss: 0.5370 - val_accuracy: 0.7019 - lr: 1.0000e-04
# Epoch 14/50
# 74/73 [==============================] - ETA: 0s - loss: 0.6036 - accuracy: 0.6650
# Epoch 14: val_accuracy did not improve from 0.70358
# 73/73 [==============================] - 44s 594ms/step - loss: 0.6036 - accuracy: 0.6650 - val_loss: 0.5960 - val_accuracy: 0.6491 - lr: 1.0000e-04
# Epoch 15/50
# 74/73 [==============================] - ETA: 0s - loss: 0.5785 - accuracy: 0.6858
# Epoch 15: val_accuracy did not improve from 0.70358
# 73/73 [==============================] - 47s 634ms/step - loss: 0.5785 - accuracy: 0.6858 - val_loss: 0.6353 - val_accuracy: 0.6116 - lr: 1.0000e-04
# Epoch 16/50
# 74/73 [==============================] - ETA: 0s - loss: 0.5880 - accuracy: 0.6833
# Epoch 16: val_accuracy did not improve from 0.70358
# 73/73 [==============================] - 44s 596ms/step - loss: 0.5880 - accuracy: 0.6833 - val_loss: 0.5399 - val_accuracy: 0.6968 - lr: 1.0000e-04
# Epoch 17/50
# 74/73 [==============================] - ETA: 0s - loss: 0.5697 - accuracy: 0.6858
# Epoch 17: val_accuracy did not improve from 0.70358
# 73/73 [==============================] - 44s 597ms/step - loss: 0.5697 - accuracy: 0.6858 - val_loss: 0.5666 - val_accuracy: 0.6457 - lr: 1.0000e-04
# Epoch 18/50
# 74/73 [==============================] - ETA: 0s - loss: 0.5693 - accuracy: 0.6897
# Epoch 18: val_accuracy improved from 0.70358 to 0.72913, saving model to /content/drive/MyDrive/BreastCancerProject/Models/weights.best.hdf5
# 73/73 [==============================] - 52s 707ms/step - loss: 0.5693 - accuracy: 0.6897 - val_loss: 0.5246 - val_accuracy: 0.7291 - lr: 1.0000e-04
# Epoch 19/50
# 74/73 [==============================] - ETA: 0s - loss: 0.
50
# 74/73 [==============================] - ETA: 0s - loss: 0.5458 - accuracy: 0.7097
# Epoch 41: val_accuracy did not improve from 0.75468
# 73/73 [==============================] - 44s 598ms/step - loss: 0.5458 - accuracy: 0.7097 - val_loss: 0.5304 - val_accuracy: 0.7342 - lr: 1.0000e-04
# Epoch 42/50
# 74/73 [==============================] - ETA: 0s - loss: 0.5485 - accuracy: 0.7033
# Epoch 42: val_accuracy did not improve from 0.75468
# 73/73 [==============================] - 46s 631ms/step - loss: 0.5485 - accuracy: 0.7033 - val_loss: 0.6365 - val_accuracy: 0.5928 - lr: 1.0000e-04
# Epoch 43/50
# 74/73 [==============================] - ETA: 0s - loss: 0.5473 - accuracy: 0.6999
# Epoch 43: val_accuracy did not improve from 0.75468
# 73/73 [==============================] - 44s 595ms/step - loss: 0.5473 - accuracy: 0.6999 - val_loss: 0.5330 - val_accuracy: 0.7206 - lr: 1.0000e-04
# Epoch 44/50
# 74/73 [==============================] - ETA: 0s - loss: 0.5454 - accuracy: 0.7089
# Epoch 44: val_accuracy did not improve from 0.75468
# 73/73 [==============================] - 44s 595ms/step - loss: 0.5454 - accuracy: 0.7089 - val_loss: 0.5322 - val_accuracy: 0.7274 - lr: 1.0000e-04
# Epoch 45/50
# 74/73 [==============================] - ETA: 0s - loss: 0.5357 - accuracy: 0.7195
# Epoch 45: val_accuracy did not improve from 0.75468
# 73/73 [==============================] - 46s 630ms/step - loss: 0.5357 - accuracy: 0.7195 - val_loss: 0.7310 - val_accuracy: 0.6371 - lr: 1.0000e-04
# Epoch 46/50
# 74/73 [==============================] - ETA: 0s - loss: 0.5338 - accuracy: 0.7199
# Epoch 46: val_accuracy did not improve from 0.75468
# 73/73 [==============================] - 47s 633ms/step - loss: 0.5338 - accuracy: 0.7199 - val_loss: 0.5969 - val_accuracy: 0.6576 - lr: 1.0000e-04
# Epoch 47/50
# 74/73 [==============================] - ETA: 0s - loss: 0.5446 - accuracy: 0.7084
# Epoch 47: val_accuracy did not improve from 0.75468
# 73/73 [==============================] - 44s 595ms/step - loss: 0.5446 - accuracy: 0.7084 - val_loss: 0.5269 - val_accuracy: 0.7121 - lr: 1.0000e-04
# Epoch 48/50
# 74/73 [==============================] - ETA: 0s - loss: 0.5356 - accuracy: 0.7093
# Epoch 48: val_accuracy did not improve from 0.75468
# 73/73 [==============================] - 46s 630ms/step - loss: 0.5356 - accuracy: 0.7093 - val_loss: 0.5864 - val_accuracy: 0.7308 - lr: 1.0000e-04
# Epoch 49/50
# 74/73 [==============================] - ETA: 0s - loss: 0.5459 - accuracy: 0.7033
# Epoch 49: val_accuracy did not improve from 0.75468
# 73/73 [==============================] - 44s 595ms/step - loss: 0.5459 - accuracy: 0.7033 - val_loss: 0.6951 - val_accuracy: 0.7036 - lr: 1.0000e-04
# Epoch 50/50
# 74/73 [==============================] - ETA: 0s - loss: 0.5270 - accuracy: 0.7157
# Epoch 50: val_accuracy did not improve from 0.75468
# 73/73 [==============================] - 44s 595ms/step - loss: 0.5270 - accuracy: 0.7157 - val_loss: 0.6718 - val_accuracy: 0.6457 - lr: 1.0000e-04

# %%
  with open('history.json', 'w') as f:
    json.dump(str(history.history), f)

# %%
history_df = pd.DataFrame(history.history)
history_df[['accuracy', 'val_accuracy']].plot()

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()

# %%
model.save(filepath)

# %% [markdown]
# # Prediction

# %%
model.load_weights(filepath)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 7, 7, 1920)        18321984
#
#  global_average_pooling2d (G  (None, 1920)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1920)              0
#
#  batch_normalization (BatchN  (None, 1920)             7680
#  ormalization)
#
#  dense (Dense)               (None, 2)                 3842
#
# =================================================================
# Total params: 18,333,506
# Trainable params: 18,100,610
# Non-trainable params: 232,896
# _________________________________________________________________

# %%
Y_val_pred = model.predict(x_val)

# %%
accuracy_score(np.argmax(y_val, axis=1), np.argmax(Y_val_pred, axis=1))
# Out:
# 0.645655877342419

# %%
Y_pred = model.predict(X_test)

# %%
tta_steps = 10
predictions = []

for i in tqdm(range(tta_steps)):
    preds = model.predict_generator(train_generator.flow(X_test, batch_size=BATCH_SIZE, shuffle=False),
                                    steps = len(X_test)/BATCH_SIZE)
    
    predictions.append(preds)
    gc.collect()
    
Y_pred_tta = np.mean(predictions, axis=0)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#
# 100%|██████████| 10/10 [00:46<00:00,  4.67s/it]

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Skin Cancer')
# Out:
# Confusion matrix, without normalization
# [[162  16]
#  [ 90  26]]

# %%
cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Skin Cancer')
# Out:
# Confusion matrix, without normalization
# [[168  10]
#  [ 93  23]]

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
classification_report( np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.64      0.94      0.77       178\n           1       0.70      0.20      0.31       116\n\n    accuracy                           0.65       294\n   macro avg       0.67      0.57      0.54       294\nweighted avg       0.66      0.65      0.59       294\n'

# %%
i=0
prop_class=[]
mis_class=[]

for i in range(len(Y_test)):
    if(np.argmax(Y_test[i])==np.argmax(Y_pred_tta[i])):
        prop_class.append(i)
    if(len(prop_class)==8):
        break

i=0
for i in range(len(Y_test)):
    if(not np.argmax(Y_test[i])==np.argmax(Y_pred_tta[i])):
        mis_class.append(i)
    if(len(mis_class)==8):
        break

# # Display first 8 images of benign
w=60
h=40
fig=plt.figure(figsize=(18, 10))
columns = 4
rows = 2

def Transfername(namecode):
    if namecode==0:
        return "Benign"
    else:
        return "Malignant"
    
for i in range(len(prop_class)):
    ax = fig.add_subplot(rows, columns, i+1)
    ax.set_title("Predicted result:"+ Transfername(np.argmax(Y_pred_tta[prop_class[i]]))
                       +"\n"+"Actual result: "+ Transfername(np.argmax(Y_test[prop_class[i]])))
    plt.imshow(X_test[prop_class[i]], interpolation='nearest')
plt.show()

# %% [markdown]
# # **INBreast Training**

# %% [markdown]
# # **Loading DataSet**

# %%
#Transfer 'jpg' images to an array IMG
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".png":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

benign_train = np.array(Dataset_loader('/content/drive/MyDrive/BreastCancerProject/DataSet/INBreastDatasetforBenignandMalignent/train/Benign',224))
malign_train = np.array(Dataset_loader('/content/drive/MyDrive/BreastCancerProject/DataSet/INBreastDatasetforBenignandMalignent/train/Malignant',224))
benign_test = np.array(Dataset_loader('/content/drive/MyDrive/BreastCancerProject/DataSet/INBreastDatasetforBenignandMalignent/test/Benign',224))
malign_test = np.array(Dataset_loader('/content/drive/MyDrive/BreastCancerProject/DataSet/INBreastDatasetforBenignandMalignent/test/Malignant',224))
# Out:
# 100%|██████████| 219/219 [00:20<00:00, 10.75it/s]
# 100%|██████████| 90/90 [00:08<00:00, 10.97it/s]
# 100%|██████████| 24/24 [00:01<00:00, 12.02it/s]
# 100%|██████████| 10/10 [00:00<00:00, 11.15it/s]

# %% [markdown]
# # **Create Labels**

# %%
# Create labels
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))

# Merge data 
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)

# Shuffle train data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# Shuffle test data
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# To categorical
Y_train = to_categorical(Y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)

# %% [markdown]
# # **Split Dataset**

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X_train, Y_train, 
    test_size=0.2, 
    random_state=11
)

# %% [markdown]
# # **Display Some Images**

# %%
# # Display first 15 images of moles, and how they are classified
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(Y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(x_train[i], interpolation='nearest')
plt.show()

# %% [markdown]
# # **DataSet Generator**

# %%
BATCH_SIZE = 16

# Using original generator
train_generator = ImageDataGenerator(
        zoom_range=2,  # set range for random zoom
        rotation_range = 90,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
    )

# %% [markdown]
# # **Load Previous Model**

# %%
from tensorflow import keras

filepath="/content/drive/MyDrive/BreastCancerProject/Models/weights.CBIS.hdf5" 
model = keras.models.load_model(filepath) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 7, 7, 1920)        18321984
#
#  global_average_pooling2d (G  (None, 1920)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1920)              0
#
#  batch_normalization (BatchN  (None, 1920)             7680
#  ormalization)
#
#  dense (Dense)               (None, 2)                 3842
#
# =================================================================
# Total params: 18,333,506
# Trainable params: 18,100,610
# Non-trainable params: 232,896
# _________________________________________________________________

# %% [markdown]
# # **Start Training**

# %%
filepath="/content/drive/MyDrive/BreastCancerProject/Models/weights.best.hdf5"
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=5,verbose=1,factor=0.2, min_lr=1e-4)
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
history = model.fit_generator(
    train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
    epochs=50,
    validation_data=(x_val, y_val),
    callbacks=[learn_control, checkpoint]
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   if __name__ == '__main__':
# Epoch 1/50
# 16/15 [===============================] - ETA: 0s - loss: 0.7765 - accuracy: 0.5466
# Epoch 1: val_accuracy improved from -inf to 0.77419, saving model to /content/drive/MyDrive/BreastCancerProject/Models/weights.best.hdf5
# 15/15 [==============================] - 36s 1s/step - loss: 0.7765 - accuracy: 0.5466 - val_loss: 0.5615 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 2/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6539 - accuracy: 0.6397
# Epoch 2: val_accuracy did not improve from 0.77419
# 15/15 [==============================] - 5s 329ms/step - loss: 0.6539 - accuracy: 0.6397 - val_loss: 0.5515 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 3/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6481 - accuracy: 0.6802
# Epoch 3: val_accuracy did not improve from 0.77419
# 15/15 [==============================] - 5s 326ms/step - loss: 0.6481 - accuracy: 0.6802 - val_loss: 1.2551 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 4/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6890 - accuracy: 0.6356
# Epoch 4: val_accuracy did not improve from 0.77419
# 15/15 [==============================] - 5s 327ms/step - loss: 0.6890 - accuracy: 0.6356 - val_loss: 1.0643 - val_accuracy: 0.3548 - lr: 1.0000e-04
# Epoch 5/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6048 - accuracy: 0.7045
# Epoch 5: val_accuracy did not improve from 0.77419
# 15/15 [==============================] - 5s 341ms/step - loss: 0.6048 - accuracy: 0.7045 - val_loss: 0.9979 - val_accuracy: 0.4839 - lr: 1.0000e-04
# Epoch 6/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6721 - accuracy: 0.6599
# Epoch 6: val_accuracy did not improve from 0.77419
# 15/15 [==============================] - 5s 334ms/step - loss: 0.6721 - accuracy: 0.6599 - val_loss: 0.5800 - val_accuracy: 0.7419 - lr: 1.0000e-04
# Epoch 7/50
# 16/15 [===============================] - ETA: 0s - loss: 0.
50
# 16/15 [===============================] - ETA: 0s - loss: 0.6331 - accuracy: 0.6883
# Epoch 18: val_accuracy did not improve from 0.77419
# 15/15 [==============================] - 5s 328ms/step - loss: 0.6331 - accuracy: 0.6883 - val_loss: 0.5482 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 19/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6315 - accuracy: 0.6761
# Epoch 19: val_accuracy did not improve from 0.77419
# 15/15 [==============================] - 5s 324ms/step - loss: 0.6315 - accuracy: 0.6761 - val_loss: 0.6246 - val_accuracy: 0.6935 - lr: 1.0000e-04
# Epoch 20/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6445 - accuracy: 0.6761
# Epoch 20: val_accuracy did not improve from 0.77419
# 15/15 [==============================] - 5s 327ms/step - loss: 0.6445 - accuracy: 0.6761 - val_loss: 0.6720 - val_accuracy: 0.4516 - lr: 1.0000e-04
# Epoch 21/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6268 - accuracy: 0.6680
# Epoch 21: val_accuracy did not improve from 0.77419
# 15/15 [==============================] - 5s 330ms/step - loss: 0.6268 - accuracy: 0.6680 - val_loss: 0.7096 - val_accuracy: 0.7581 - lr: 1.0000e-04
# Epoch 22/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6345 - accuracy: 0.6883
# Epoch 22: val_accuracy did not improve from 0.77419
# 15/15 [==============================] - 5s 329ms/step - loss: 0.6345 - accuracy: 0.6883 - val_loss: 0.6957 - val_accuracy: 0.7581 - lr: 1.0000e-04
# Epoch 23/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6411 - accuracy: 0.6923
# Epoch 23: val_accuracy did not improve from 0.77419
# 15/15 [==============================] - 5s 329ms/step - loss: 0.6411 - accuracy: 0.6923 - val_loss: 0.6554 - val_accuracy: 0.6613 - lr: 1.0000e-04
# Epoch 24/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6095 - accuracy: 0.6599
# Epoch 24: val_accuracy improved from 0.77419 to 0.79032, saving model to /content/drive/MyDrive/BreastCancerProject/Models/weights.best.hdf5
# 15/15 [==============================] - 11s 704ms/step - loss: 0.6095 - accuracy: 0.6599 - val_loss: 0.5863 - val_accuracy: 0.7903 - lr: 1.0000e-04
# Epoch 25/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6077 - accuracy: 0.6923
# Epoch 25: val_accuracy did not improve from 0.79032
# 15/15 [==============================] - 5s 328ms/step - loss: 0.6077 - accuracy: 0.6923 - val_loss: 1.3450 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 26/50
# 16/15 [===============================] - ETA: 0s - loss: 0.5961 - accuracy: 0.6964
# Epoch 26: val_accuracy did not improve from 0.79032
# 15/15 [==============================] - 6s 353ms/step - loss: 0.5961 - accuracy: 0.6964 - val_loss: 1.0641 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 27/50
# 16/15 [===============================] - ETA: 0s - loss: 0.5841 - accuracy: 0.7166
# Epoch 27: val_accuracy did not improve from 0.79032
# 15/15 [==============================] - 5s 353ms/step - loss: 0.5841 - accuracy: 0.7166 - val_loss: 1.0507 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 28/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6242 - accuracy: 0.7166
# Epoch 28: val_accuracy did not improve from 0.79032
# 15/15 [==============================] - 5s 328ms/step - loss: 0.6242 - accuracy: 0.7166 - val_loss: 0.6344 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 29/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6284 - accuracy: 0.6802
# Epoch 29: val_accuracy did not improve from 0.79032
# 15/15 [==============================] - 5s 330ms/step - loss: 0.6284 - accuracy: 0.6802 - val_loss: 0.5935 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 30/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6176 - accuracy: 0.6761
# Epoch 30: val_accuracy did not improve from 0.79032
# 15/15 [==============================] - 5s 330ms/step - loss: 0.6176 - accuracy: 0.6761 - val_loss: 0.5463 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 31/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6132 - accuracy: 0.7085
# Epoch 31: val_accuracy improved from 0.79032 to 0.80645, saving model to /content/drive/MyDrive/BreastCancerProject/Models/weights.best.hdf5
# 15/15 [==============================] - 10s 686ms/step - loss: 0.6132 - accuracy: 0.7085 - val_loss: 0.5295 - val_accuracy: 0.8065 - lr: 1.0000e-04
# Epoch 32/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6236 - accuracy: 0.6802
# Epoch 32: val_accuracy did not improve from 0.80645
# 15/15 [==============================] - 5s 328ms/step - loss: 0.6236 - accuracy: 0.6802 - val_loss: 0.5597 - val_accuracy: 0.7903 - lr: 1.0000e-04
# Epoch 33/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6135 - accuracy: 0.7045
# Epoch 33: val_accuracy did not improve from 0.80645
# 15/15 [==============================] - 6s 371ms/step - loss: 0.6135 - accuracy: 0.7045 - val_loss: 0.5867 - val_accuracy: 0.6452 - lr: 1.0000e-04
# Epoch 34/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6396 - accuracy: 0.6437
# Epoch 34: val_accuracy did not improve from 0.80645
# 15/15 [==============================] - 5s 329ms/step - loss: 0.6396 - accuracy: 0.6437 - val_loss: 0.5890 - val_accuracy: 0.7097 - lr: 1.0000e-04
# Epoch 35/50
# 16/15 [===============================] - ETA: 0s - loss: 0.5454 - accuracy: 0.7368
# Epoch 35: val_accuracy did not improve from 0.80645
# 15/15 [==============================] - 5s 329ms/step - loss: 0.5454 - accuracy: 0.7368 - val_loss: 0.5452 - val_accuracy: 0.7097 - lr: 1.0000e-04
# Epoch 36/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6144 - accuracy: 0.7085
# Epoch 36: val_accuracy improved from 0.80645 to 0.82258, saving model to /content/drive/MyDrive/BreastCancerProject/Models/weights.best.hdf5
# 15/15 [==============================] - 11s 751ms/step - loss: 0.6144 - accuracy: 0.7085 - val_loss: 0.4120 - val_accuracy: 0.8226 - lr: 1.0000e-04
# Epoch 37/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6152 - accuracy: 0.6802
# Epoch 37: val_accuracy did not improve from 0.82258
# 15/15 [==============================] - 5s 328ms/step - loss: 0.6152 - accuracy: 0.6802 - val_loss: 0.5826 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 38/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6110 - accuracy: 0.7166
# Epoch 38: val_accuracy did not improve from 0.82258
# 15/15 [==============================] - 5s 331ms/step - loss: 0.6110 - accuracy: 0.7166 - val_loss: 0.5477 - val_accuracy: 0.8065 - lr: 1.0000e-04
# Epoch 39/50
# 16/15 [===============================] - ETA: 0s - loss: 0.5929 - accuracy: 0.7126
# Epoch 39: val_accuracy improved from 0.82258 to 0.85484, saving model to /content/drive/MyDrive/BreastCancerProject/Models/weights.best.hdf5
# 15/15 [==============================] - 11s 704ms/step - loss: 0.5929 - accuracy: 0.7126 - val_loss: 0.3330 - val_accuracy: 0.8548 - lr: 1.0000e-04
# Epoch 40/50
# 16/15 [===============================] - ETA: 0s - loss: 0.5956 - accuracy: 0.6964
# Epoch 40: val_accuracy improved from 0.85484 to 0.88710, saving model to /content/drive/MyDrive/BreastCancerProject/Models/weights.best.hdf5
# 15/15 [==============================] - 10s 624ms/step - loss: 0.5956 - accuracy: 0.6964 - val_loss: 0.3815 - val_accuracy: 0.8871 - lr: 1.0000e-04
# Epoch 41/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6152 - accuracy: 0.6842
# Epoch 41: val_accuracy did not improve from 0.88710
# 15/15 [==============================] - 5s 331ms/step - loss: 0.6152 - accuracy: 0.6842 - val_loss: 0.5800 - val_accuracy: 0.7581 - lr: 1.0000e-04
# Epoch 42/50
# 16/15 [===============================] - ETA: 0s - loss: 0.5913 - accuracy: 0.7126
# Epoch 42: val_accuracy did not improve from 0.88710
# 15/15 [==============================] - 6s 358ms/step - loss: 0.5913 - accuracy: 0.7126 - val_loss: 0.5653 - val_accuracy: 0.7419 - lr: 1.0000e-04
# Epoch 43/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6188 - accuracy: 0.6761
# Epoch 43: val_accuracy did not improve from 0.88710
# 15/15 [==============================] - 5s 329ms/step - loss: 0.6188 - accuracy: 0.6761 - val_loss: 0.6563 - val_accuracy: 0.5806 - lr: 1.0000e-04
# Epoch 44/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6087 - accuracy: 0.6842
# Epoch 44: val_accuracy did not improve from 0.88710
# 15/15 [==============================] - 5s 333ms/step - loss: 0.6087 - accuracy: 0.6842 - val_loss: 0.4668 - val_accuracy: 0.7903 - lr: 1.0000e-04
# Epoch 45/50
# 16/15 [===============================] - ETA: 0s - loss: 0.5798 - accuracy: 0.7004
# Epoch 45: val_accuracy did not improve from 0.88710
# 15/15 [==============================] - 5s 345ms/step - loss: 0.5798 - accuracy: 0.7004 - val_loss: 0.3888 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 46/50
# 16/15 [===============================] - ETA: 0s - loss: 0.5878 - accuracy: 0.7045
# Epoch 46: val_accuracy did not improve from 0.88710
# 15/15 [==============================] - 5s 330ms/step - loss: 0.5878 - accuracy: 0.7045 - val_loss: 0.9037 - val_accuracy: 0.8387 - lr: 1.0000e-04
# Epoch 47/50
# 16/15 [===============================] - ETA: 0s - loss: 0.5952 - accuracy: 0.6599
# Epoch 47: val_accuracy did not improve from 0.88710
# 15/15 [==============================] - 5s 332ms/step - loss: 0.5952 - accuracy: 0.6599 - val_loss: 0.5225 - val_accuracy: 0.7581 - lr: 1.0000e-04
# Epoch 48/50
# 16/15 [===============================] - ETA: 0s - loss: 0.5376 - accuracy: 0.7287
# Epoch 48: val_accuracy did not improve from 0.88710
# 15/15 [==============================] - 5s 332ms/step - loss: 0.5376 - accuracy: 0.7287 - val_loss: 0.5612 - val_accuracy: 0.7742 - lr: 1.0000e-04
# Epoch 49/50
# 16/15 [===============================] - ETA: 0s - loss: 0.5984 - accuracy: 0.7166
# Epoch 49: val_accuracy did not improve from 0.88710
# 15/15 [==============================] - 5s 331ms/step - loss: 0.5984 - accuracy: 0.7166 - val_loss: 0.3606 - val_accuracy: 0.8710 - lr: 1.0000e-04
# Epoch 50/50
# 16/15 [===============================] - ETA: 0s - loss: 0.6008 - accuracy: 0.6923
# Epoch 50: val_accuracy did not improve from 0.88710
# 15/15 [==============================] - 5s 328ms/step - loss: 0.6008 - accuracy: 0.6923 - val_loss: 0.6631 - val_accuracy: 0.7742 - lr: 1.0000e-04

# %% [markdown]
# # **Save Results in Json File**

# %%
with open('history.json', 'w') as f:
    json.dump(str(history.history), f)

# %% [markdown]
# # **Save Model**

# %%
filepath = '/content/drive/MyDrive/BreastCancerData/weights_INBreast.hdf5'
model.save(filepath)

# %% [markdown]
# # **Plot Results**

# %%
history_df = pd.DataFrame(history.history)
history_df[['accuracy', 'val_accuracy']].plot()

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()

# %% [markdown]
# # **Load Saved Model**

# %%
model.load_weights(filepath)

# %% [markdown]
# # **Prediction**

# %%
Y_val_pred = model.predict(x_val) 
accuracy_score(np.argmax(y_val, axis=1), np.argmax(Y_val_pred, axis=1))
# Out:
# 0.7741935483870968

# %%
Y_pred = model.predict(X_test)
tta_steps = 10
predictions = []

for i in tqdm(range(tta_steps)):
    preds = model.predict_generator(train_generator.flow(X_test, batch_size=BATCH_SIZE, shuffle=False),
                                    steps = len(X_test)/BATCH_SIZE)
    
    predictions.append(preds)
    gc.collect()
    
Y_pred_tta = np.mean(predictions, axis=0)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   import sys
# 100%|██████████| 10/10 [00:13<00:00,  1.34s/it]

# %% [markdown]
# # **Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Skin Cancer')
# Out:
# Confusion matrix, without normalization
# [[24  0]
#  [10  0]]

# %%
cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Skin Cancer')
# Out:
# Confusion matrix, without normalization
# [[24  0]
#  [10  0]]

# %% [markdown]
# # **Classification Report**

# %%
from sklearn.metrics import classification_report
classification_report( np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# '              precision    recall  f1-score   support\n\n           0       0.71      1.00      0.83        24\n           1       0.00      0.00      0.00        10\n\n    accuracy                           0.71        34\n   macro avg       0.35      0.50      0.41        34\nweighted avg       0.50      0.71      0.58        34\n'

# %% [markdown]
# # **Prediction Results**

# %%
i=0
prop_class=[]
mis_class=[]

for i in range(len(Y_test)):
    if(np.argmax(Y_test[i])==np.argmax(Y_pred_tta[i])):
        prop_class.append(i)
    if(len(prop_class)==8):
        break

i=0
for i in range(len(Y_test)):
    if(not np.argmax(Y_test[i])==np.argmax(Y_pred_tta[i])):
        mis_class.append(i)
    if(len(mis_class)==8):
        break

# # Display first 8 images of benign
w=60
h=40
fig=plt.figure(figsize=(18, 10))
columns = 4
rows = 2

def Transfername(namecode):
    if namecode==0:
        return "Benign"
    else:
        return "Malignant"
    
for i in range(len(prop_class)):
    ax = fig.add_subplot(rows, columns, i+1)
    ax.set_title("Predicted result:"+ Transfername(np.argmax(Y_pred_tta[prop_class[i]]))
                       +"\n"+"Actual result: "+ Transfername(np.argmax(Y_test[prop_class[i]])))
    plt.imshow(X_test[prop_class[i]], interpolation='nearest')
plt.show()
